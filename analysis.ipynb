# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('athlete_events.csv')
region_df = pd.read_csv('noc_regions.csv')

# %%
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %%
df.shape
# Out:
# (271116, 15)

# %%
df = df[df['Season'] == 'Summer']

# %%
df.shape
# Out:
# (222552, 15)

# %%
df.tail()
# Out:
#             ID                          Name Sex   Age  Height  Weight  \
# 271106  135565      Fernando scar Zylberberg   M  27.0   168.0    76.0
# 271107  135566    James Francis "Jim" Zylker   M  21.0   175.0    75.0
# 271108  135567  Aleksandr Viktorovich Zyuzin   M  24.0   183.0    72.0
# 271109  135567  Aleksandr Viktorovich Zyuzin   M  28.0   183.0    72.0
# 271110  135568        Olga Igorevna Zyuzkova   F  33.0   171.0    69.0
#
#                  Team  NOC        Games  Year  Season            City  \
# 271106      Argentina  ARG  2004 Summer  2004  Summer          Athina
# 271107  United States  USA  1972 Summer  1972  Summer          Munich
# 271108         Russia  RUS  2000 Summer  2000  Summer          Sydney
# 271109         Russia  RUS  2004 Summer  2004  Summer          Athina
# 271110        Belarus  BLR  2016 Summer  2016  Summer  Rio de Janeiro
#
#              Sport                                   Event Medal
# 271106      Hockey                     Hockey Men's Hockey   NaN
# 271107    Football                 Football Men's Football   NaN
# 271108      Rowing  Rowing Men's Lightweight Coxless Fours   NaN
# 271109      Rowing  Rowing Men's Lightweight Coxless Fours   NaN
# 271110  Basketball           Basketball Women's Basketball   NaN

# %%
df.sample(5)
# Out:
#            ID                                Name Sex   Age  Height  Weight  \
# 191180  96004                     Daniel Pon Mony   M  26.0     NaN    59.0
# 52722   27075  Anna Maria "Ans" Dekker (-Pieters)   F  17.0   167.0    54.0
# 77948   39581             Elena Georgescu-Nedelcu   F  44.0   160.0    55.0
# 65565   33553              Patrick Aloysius Ewing   M  21.0   213.0   109.0
# 146166  73345                      Michele Maffei   M  29.0   178.0    79.0
#
#                  Team  NOC        Games  Year  Season         City  \
# 191180          India  IND  1948 Summer  1948  Summer       London
# 52722     Netherlands  NED  1972 Summer  1972  Summer       Munich
# 77948         Romania  ROU  2008 Summer  2008  Summer      Beijing
# 65565   United States  USA  1984 Summer  1984  Summer  Los Angeles
# 146166          Italy  ITA  1976 Summer  1976  Summer     Montreal
#
#                 Sport                              Event   Medal
# 191180  Weightlifting  Weightlifting Men's Featherweight     NaN
# 52722      Gymnastics    Gymnastics Women's Balance Beam     NaN
# 77948          Rowing        Rowing Women's Coxed Eights  Bronze
# 65565      Basketball        Basketball Men's Basketball    Gold
# 146166        Fencing          Fencing Men's Sabre, Team  Silver

# %%
region_df.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
df = df.merge(region_df, on='NOC', how='left')

# %%
df.sample(5)
# Out:
#            ID                     Name Sex   Age  Height  Weight  \
# 92553   56784             Fujio Kakuta   M  21.0     NaN     NaN
# 146928  89713  Peter Mattias Oscarsson   M  21.0   183.0    85.0
# 96104   58967     Nicolas "Nic" Kettel   M  22.0   170.0    70.0
# 86739   53119     Joseph "Joe" Jackson   M  39.0   183.0     NaN
# 54759   33471              Scott Evans   M  20.0   182.0    78.0
#
#                  Team  NOC        Games  Year  Season         City  \
# 92553           Japan  JPN  1932 Summer  1932  Summer  Los Angeles
# 146928         Sweden  SWE  1996 Summer  1996  Summer      Atlanta
# 96104      Luxembourg  LUX  1948 Summer  1948  Summer       London
# 86739   United States  USA  1920 Summer  1920  Summer    Antwerpen
# 54759         Ireland  IRL  2008 Summer  2008  Summer      Beijing
#
#              Sport                                       Event Medal  \
# 92553   Gymnastics             Gymnastics Men's Floor Exercise   NaN
# 146928    Canoeing    Canoeing Men's Kayak Fours, 1,000 metres   NaN
# 96104     Football                     Football Men's Football   NaN
# 86739     Shooting  Shooting Men's Running Target, Double Shot   NaN
# 54759    Badminton                     Badminton Men's Singles   NaN
#
#             region notes
# 92553        Japan   NaN
# 146928      Sweden   NaN
# 96104   Luxembourg   NaN
# 86739          USA   NaN
# 54759      Ireland   NaN

# %%
df['region'].unique().shape
# Out:
# (206,)

# %%
df.isnull().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9189
# Height     51857
# Weight     53854
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     188464
# region       370
# notes     218151
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(1385)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Medal'].value_counts()
# Out:
# Medal
# Gold      11456
# Bronze    11409
# Silver    11212
# Name: count, dtype: int64

# %%
df = pd.concat([df, pd.get_dummies(df['Medal'])], axis=1)

# %%
df.groupby('NOC').sum()[['Gold', 'Silver', 'Bronze']].sort_values('Gold', ascending=False).reset_index()
# Out:
#      NOC  Gold  Silver  Bronze
# 0    USA  2472    1333    1197
# 1    URS   832     635     596
# 2    GBR   635     729     620
# 3    GER   592     538     649
# 4    ITA   518     474     454
# ..   ...   ...     ...     ...
# 225  WIF     0       0       5
# 226  YEM     0       0       0
# 227  YAR     0       0       0
# 228  YMD     0       0       0
# 229  ZAM     0       1       1
#
# [230 rows x 4 columns]

# %%
df[(df['NOC'] == 'IND') & (df['Medal'] == 'Gold')].sort_values('Year')
# Out:
#             ID                           Name Sex   Age  Height  Weight  \
# 4186      2699                    Shaukat Ali   M  30.0     NaN     NaN
# 4460      2864            Richard James Allen   M  25.0   172.0     NaN
# 32103    19716               Dhyan Chand Bais   M  22.0   169.0     NaN
# 123521   75490  George Eric McCarthy Marthins   M  22.0     NaN     NaN
# 96371    59150     Feroz-ud-Din "Feroze" Khan   M  23.0     NaN     NaN
# ...        ...                            ...  ..   ...     ...     ...
# 57165    34901               Merwyn Fernandis   M  21.0   159.0    62.0
# 94617    58105        Maharaj Krishon Kaushik   M  25.0   163.0    60.0
# 181714  111131             Ravinder Pal Singh   M  19.0   168.0    63.0
# 191759  117232             Dung Dung Sylvanus   M  31.0   160.0    62.0
# 18444    11601                 Abhinav Bindra   M  25.0   173.0    70.0
#
#          Team  NOC        Games  Year  Season       City     Sport  \
# 4186    India  IND  1928 Summer  1928  Summer  Amsterdam    Hockey
# 4460    India  IND  1928 Summer  1928  Summer  Amsterdam    Hockey
# 32103   India  IND  1928 Summer  1928  Summer  Amsterdam    Hockey
# 123521  India  IND  1928 Summer  1928  Summer  Amsterdam    Hockey
# 96371   India  IND  1928 Summer  1928  Summer  Amsterdam    Hockey
# ...       ...  ...          ...   ...     ...        ...       ...
# 57165   India  IND  1980 Summer  1980  Summer     Moskva    Hockey
# 94617   India  IND  1980 Summer  1980  Summer     Moskva    Hockey
# 181714  India  IND  1980 Summer  1980  Summer     Moskva    Hockey
# 191759  India  IND  1980 Summer  1980  Summer     Moskva    Hockey
# 18444   India  IND  2008 Summer  2008  Summer    Beijing  Shooting
#
#                                       Event Medal region notes  Bronze  Gold  \
# 4186                    Hockey Men's Hockey  Gold  India   NaN   False  True
# 4460                    Hockey Men's Hockey  Gold  India   NaN   False  True
# 32103                   Hockey Men's Hockey  Gold  India   NaN   False  True
# 123521                  Hockey Men's Hockey  Gold  India   NaN   False  True
# 96371                   Hockey Men's Hockey  Gold  India   NaN   False  True
# ...                                     ...   ...    ...   ...     ...   ...
# 57165                   Hockey Men's Hockey  Gold  India   NaN   False  True
# 94617                   Hockey Men's Hockey  Gold  India   NaN   False  True
# 181714                  Hockey Men's Hockey  Gold  India   NaN   False  True
# 191759                  Hockey Men's Hockey  Gold  India   NaN   False  True
# 18444   Shooting Men's Air Rifle, 10 metres  Gold  India   NaN   False  True
#
#         Silver
# 4186     False
# 4460     False
# 32103    False
# 123521   False
# 96371    False
# ...        ...
# 57165    False
# 94617    False
# 181714   False
# 191759   False
# 18444    False
#
# [131 rows x 20 columns]

# %%
medal_tally = df.drop_duplicates(subset=['Team', 'NOC', 'Games', 'Year', 'City', 'Sport', 'Event', 'Medal'])

# %%
medal_tally = medal_tally.groupby('NOC').sum()[['Gold', 'Silver', 'Bronze']].sort_values('Gold', ascending=False).reset_index()

# %%
medal_tally.shape
# Out:
# (105636, 20)

# %%
medal_tally[medal_tally['NOC'] == 'IND']
# Out:
#     NOC  Gold  Silver  Bronze
# 50  IND     9       7      12
